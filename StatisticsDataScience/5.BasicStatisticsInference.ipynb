# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarnished2/DataScientist/blob/main/StatisticsDataScience/5.BasicStatisticsInference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pramaditya Ardian Saputra

# %% [markdown]
# Ingatlah materi Central Limit Theorem dan Distribusi Normal

# %% [markdown]
# Kita dapat membuat Central Limit Theorem dengan contoh kerja yang melibatkan pelemparan dadu.
#
# Ingatlah bahwa dadu adalah kubus dengan angka yang berbeda di setiap sisinya dari 1 hingga 6. Setiap nomor memiliki kemungkinan 1-sampai-6 untuk muncul dari pelemparan yang menggelinding. Distribusi angka yang muncul dari pelemparan dadu adalah seragam dengan kemungkinan yang sama.
#
# Kita dapat menggunakan fungsi randint() NumPy untuk menghasilkan sejumlah lemparan dadu acak (misalnya 50) antara 1 dan 6.

# %%
# generate a sample of die rolls
# generate random dice rolls
from numpy.random import seed
from numpy.random import randint
from numpy import mean

# %%
# seed the random number generator
seed(1)
# generate a sample of die rolls
rolls = randint(1, 7, 50)
print(rolls)
print(mean(rolls))
# Out:
# [6 4 5 1 2 4 6 1 1 2 5 6 5 2 3 5 6 3 5 4 5 3 5 6 3 5 2 2 1 6 2 2 6 2 2 1 5
#  2 1 1 6 4 3 2 1 4 6 2 2 4]
# 3.44

# %% [markdown]
# Didapatkan rata-rata setiap dadu yang muncul adalah 3.44.

# %% [markdown]
# Lalu kemudian silakan ulangi proses ini beberapa kali, seperti 1.000. Ini akan memberi kita hasil 1.000 rata-rata sampel. Tentukan estimasi titik Dan bagaimana gambarnya?

# %%
#Jawab
import matplotlib.pyplot as plt
seed(1)

means = [mean(randint(1, 7, 50)) for _ in range(1000)]

plt.hist(means)
# Out:
# (array([ 16.,  31., 109., 154., 239., 223., 133.,  73.,  21.,   1.]),
#  array([2.82 , 2.962, 3.104, 3.246, 3.388, 3.53 , 3.672, 3.814, 3.956,
#         4.098, 4.24 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Buatlah sebuah simulasi sampel random dari berat badan seorang pria (kisaran antara 60 sampai 90 kg), dengan ukuran n=50. Kemudian lakukan simulasi beberapa kali sampai n tak hingga dan bagaimana bentuk distribusinya? Tentukan estimasi titik dan bagaimana bentuk gambarnya?

# %%
#Jawab
seed(1)
weight = randint(60,90,50)
means = [mean(randint(60, 90, 50)) for i in range(1000)]
plt.hist(means)
# Out:
# (array([  5.,  20.,  76., 132., 200., 239., 165.,  98.,  49.,  16.]),
#  array([70.82 , 71.524, 72.228, 72.932, 73.636, 74.34 , 75.044, 75.748,
#         76.452, 77.156, 77.86 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
misal = pd.DataFrame({"Nama":["Azri","aufa","anjasmara","bayuzen",'adam',"agustine"],
                      "hari":["selasa","rabu","rabu","kamis","kamis","jumat"],
                      "jenis_kelamin":["p","l","p","l","p","p"]})
misal
# Out:
#         Nama    hari jenis_kelamin
# 0       Azri  selasa             p
# 1       aufa    rabu             l
# 2  anjasmara    rabu             p
# 3    bayuzen   kamis             l
# 4       adam   kamis             p
# 5   agustine   jumat             p

# %%
misal['jenis_kelamin'].str.contains("p")
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# Name: jenis_kelamin, dtype: bool

# %%
misal[misal["jenis_kelamin"]=="l"]
# Out:
#       Nama   hari jenis_kelamin
# 1     aufa   rabu             l
# 3  bayuzen  kamis             l

# %%
misal[misal["jenis_kelamin"].isin(["p"])]
# Out:
#         Nama    hari jenis_kelamin
# 0       Azri  selasa             p
# 2  anjasmara    rabu             p
# 4       adam   kamis             p
# 5   agustine   jumat             p

# %%
misal.sort_values("Nama",ascending=False).reset_index(drop=True)
# Out:
#         Nama    hari jenis_kelamin
# 0    bayuzen   kamis             l
# 1       aufa    rabu             l
# 2  anjasmara    rabu             p
# 3   agustine   jumat             p
# 4       adam   kamis             p
# 5       Azri  selasa             p

# %%
import time
# %time
misal[(misal['jenis_kelamin']=="p")]
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.68 µs
#         Nama    hari jenis_kelamin
# 0       Azri  selasa             p
# 2  anjasmara    rabu             p
# 4       adam   kamis             p
# 5   agustine   jumat             p

# %%
misal[misal['jenis_kelamin'].str.contains("p")]
# Out:
#         Nama    hari jenis_kelamin
# 0       Azri  selasa             p
# 2  anjasmara    rabu             p
# 4       adam   kamis             p
# 5   agustine   jumat             p
